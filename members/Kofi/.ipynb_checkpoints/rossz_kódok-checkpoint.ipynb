# %% [markdown]
# ### Mi a hiba az alábbi kódokban? Javítsd ki őket!

# %% [markdown]
# #### Annyi jupyter tutor, ami ehhez a házihoz remélhetőleg elég lesz.
#
# - Úgy jelöltök ki cellát, hogy belekattintotok.
# - A kijelölt cellát a nagy RUN gombra kattinva tudjátok lefuttatni. Illeve a CTRL+ENTER és SHIFT+ENTER kombinációval. Az előbbi csak lefuttatja a kijelölt cellát, míg az utóbbi továbblép a következő cellára és azt jelöli ki.
# - Ha véletlenül örökké futna egy kódrészlet akkor a standard STOP gombbal állíthatjátok le a futást.
# - Ha ennél nagyobb a baj akkor a Kernel fül alatt Restartoljatok.
# - Illetve a változtatásaitokat menteni is kell standard Save gomb vagy CTRL+S.

# %% [markdown]
# #### #1

# %%
def egy():
    l1 = [3, 5, 24, 9, 15, -4, 87]
    l2 = [6, 17, 134, -11, 26, -1, 1]

    #A beépített len függvény egy iterálható objektum elemeinek számát adja visszatérési értékként.
    #Pl. lista elemeinek száma
    for n in range(len(l1)):

        if l1[n] > l2[n]:
            print(n)
egy()
# Out:
# 3
# 6

# %% [markdown]
# #### #2

# %%
def ketto(x, y, z):
    a = 'háromszög'
    if x + y > z and x + z > y and y + z > x:
        a = 'háromszög'
    
    if a == 'háromszög':
        return (x, y, z)
    else:
        return 'semmi'

ketto(1,2,3)
# Out:
# (1, 2, 3)

# %% [markdown]
# #### #3

# %%
def harom():
    k = 1
    s = 0

    while k <= 100:

        if k % 2 == 0:
            s = s + k
            return s
        else:
            return k

harom()
# Out:
# 1

# %% [markdown]
# #### #4

# %%
def negy():
    t = [0,1,4,3]

    for i in range(len(t)):

        if (len('alma') == len(t)) & (t[i] < 4):

            None
        else:
            return 'hiba'
            
negy()
# Out:
# 'hiba'

# %% [markdown]
# #### #5

# %%
def ot():
    input_lista = [112,4234,721,1002,5982,1035]
    out = []

    for i in range():
        if input_lista[i] < input_lista[i+1]:

             out[i] == input_lista[i]

        return out

ot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-0a73d3b9ba36> in <module>
#      10         return out
#      11
# ---> 12 ot()
#
# <ipython-input-5-0a73d3b9ba36> in ot()
#       3     out = []
#       4
# ----> 5     for i in range():
#       6         if input_lista[i] < input_lista[i+1]:
#       7
#
# TypeError: range expected 1 arguments, got 0

# %% [markdown]
# #### #6

# %%
def hat():
    l = [1,1,1,1,1]

    for i in l:
        while l[i] == 1:

            if l[i+1] == i:

                l[i] += 1
                
                return l

            else:

                'Error'
            
hat()
# Out:
# [1, 2, 1, 1, 1]

# %% [markdown]
# #### #7

# %%
def het():
    genya = 0
    
    for i in range(0, 100,5):
        genya += i/10

    return genya
    
het()
# Out:
# 95.0

# %% [markdown]
# #### #8

# %%
def nyolc():
    banka = "almamáter"
    tanga = ""
    for lanka in banka:
        if lanka > tanga:
            tanga = lanka
        else
            return kifogytam
        
    return tanga
    
nyolc()
# Out:
#   File "<ipython-input-8-e83d74a8efad>", line 7
#     else
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### #9

# %%
lányán=True
árán="árán"
def kilenc():
    árán = ""
    száján = "szárán"
    while len(árán) < 5:
        árván = száján * 2
        kárán = len(száján) // 3
        
        for bárány in száján:
                if száján[kárán] == bárány:
                    álcám = True
                else:
                    álcám = False
        
        if álcám:
            lányán = False
            fácán = True
        else:
            lányán = True
            fácán = False
        
        if lányán:
            árán += "m"
        elif fácán:
            árán += "n"
        else:
            hamutálcán = "pusztulásán"     
    return árán

kilenc()
# Out:
# 'mmmmm'
