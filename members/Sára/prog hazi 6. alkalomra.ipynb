# %% [markdown]
# Prog házi 6. alkalom
# Advent of Code 2018/1

# %%
with open('input1.txt') as fp:
    file_contents = fp.read()

# %%
lista=file_contents.split()

# %%
for i in range(0, len(lista)): 
    lista[i] = int(lista[i])

# %%
sum(lista)
# Out:
# 406

# %%
x=0
lista2=[]
lista2.append(int("0"))
lista3=set(lista2)
for u in range(1,138):
    for i in range(len(lista)):
        x+=lista[i]
        lista2.append(x)
    lista3=set(lista2)
    if len(lista2)!=len(lista3):
        print (u)
        break

# %%
lista4=[]
for i in range(len(lista)):
        x+=lista[i]
        lista4.append(x)

# %%
print(len(lista2))
print(len(lista3))
# Out:
# 138919
# 138919

# %%
for x in range(len(lista4)):
       for y in range(len(lista2)):
            if lista4[x]==lista2[y]:
                print (lista4[x])
                break
# Out:
# 312
# 320
# 311
# 296
# 293
# 277
# 287
# 276
# 285
# 290
# 294
# 301
# 281
# 266
# 265
# 255
# 244
# 256
# 245
# 261
# 282
# 279
# 283
# 284
# 275
# 273
# 267
# 260
# 269
# 258
# 257
# 253
# 268
# 264
# 251
# 250
# 249
# 259
# 242
# 227
# 210
# 221
# 230
# 233
# 224
# 237
# 239
# 236
# 219
# 238
# 222
# 218
# 226
# 223
# 228
# 216
# 232
# 240
# 225
# 206
# 198
# 195
# 182
# 177
# 161
# 164
# 166
# 176
# 171
# 173
# 187
# 197
# 205
# 194
# 196
# 190
# 199
# 207
# 214
# 220
# 217
# 211
# 200
# 212
# 189
# 178
# 191
# 213
# 231
# 252
# 270
# 289
# 295
# 292
# 297
# 314
# 321
# 317
# 330
# 325
# 338
# 356
# 366
# 359
# 371
# 382
# 372
# 365
# 379
# 385
# 369
# 389
# 405
# 404
# 410
# 396
# 411
# 409
# 384
# 397
# 436
# 425
# 416
# 450
# 390
# 376
# 354
# 327
# 315
# 305
# 308
# 328
# 331
# 339
# 346
# 336
# 322
# 334
# 343
# 337
# 345
# 326
# 316
# 300
# 286
# 302
# 298
# 278
# 288
# 271
# 262
# 247
# 263
# 274
# 254
# 243
# 229
# 201
# 185
# 183
# 204
# 186
# 203
# 208
# 202
# 184
# ...
